# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv("Progetto computer science\\adoptions\\dogs.csv")
dataset1 = pd.read_csv("Progetto computer science\\adoptions\\dogTravel.csv")
dataset2 = pd.read_csv("Progetto computer science\\adoptions\\NST-EST2021-POP.csv")

dataset.head()
# Out:
#          id org_id                                                url type.x  \
# 0  46042150  NV163  https://www.petfinder.com/dog/harley-46042150/...    Dog
# 1  46042002  NV163  https://www.petfinder.com/dog/biggie-46042002/...    Dog
# 2  46040898   NV99  https://www.petfinder.com/dog/ziggy-46040898/n...    Dog
# 3  46039877  NV202  https://www.petfinder.com/dog/gypsy-46039877/n...    Dog
# 4  46039306  NV184  https://www.petfinder.com/dog/theo-46039306/nv...    Dog
#
#   species                   breed_primary breed_secondary  breed_mixed  \
# 0     Dog  American Staffordshire Terrier     Mixed Breed         True
# 1     Dog                Pit Bull Terrier     Mixed Breed         True
# 2     Dog                        Shepherd             NaN        False
# 3     Dog             German Shepherd Dog             NaN        False
# 4     Dog                       Dachshund             NaN        False
#
#    breed_unknown      color_primary  ... contact_city contact_state  \
# ...

# %%
dataset1.head()
# Out:
#    index        id contact_city contact_state  \
# 0      0  44520267        Anoka            MN
# 1      1  44698509    Groveland            FL
# 2      2  45983838    Adamstown            MD
# 3      3  44475904  Saint Cloud            MN
# 4      4  43877389       Pueblo            CO
#
#                                          description        found    manual  \
# 0  Boris is a handsome mini schnauzer who made hi...     Arkansas       NaN
# 1  Duke is an almost 2 year old Potcake from Abac...       Abacos   Bahamas
# 2  Zac Woof-ron is a heartthrob movie star lookin...         Adam  Maryland
# 3  ~~Came in to the shelter as a transfer from an...      Adaptil       NaN
# 4  Palang is such a sweetheart. She loves her peo...  Afghanistan       NaN
#
#   remove still_there
# 0    NaN         NaN
# 1    NaN         NaN
# 2    NaN         NaN
# 3   True         NaN
# 4    NaN         NaN

# %%
dataset2.head()
# Out:
#       Alabama   5.024.279
# 0      Alaska     733.391
# 1     Arizona   7.151.502
# 2    Arkansas   3.011.524
# 3  California  39.538.223
# 4    Colorado   5.773.714

# %% [markdown]
# **1. Extract all dogs with status that is not adoptable**

# %%
#controllo dati unici presenti
valori_unici = dataset['status'].unique()
valori_unici
# Out:
# array(['adoptable', '2018-04-05T05:18:31+0000',
#        '2017-05-26T21:43:16+0000', '2019-09-01T15:12:06+0000',
#        '2019-08-06T12:15:58+0000', '2019-07-18T14:20:58+0000',
#        '2019-07-11T20:34:42+0000', '2019-07-11T14:16:38+0000',
#        '2019-08-10T16:00:35+0000', '2019-05-14T21:09:27+0000',
#        '2016-12-15T13:33:43+0000', '2015-09-07T12:57:27+0000',
#        '2018-07-05T00:55:08+0000', '2017-10-07T23:48:20+0000',
#        '2019-09-07T04:09:12+0000', '2019-09-13T19:39:28+0000',
#        '2019-04-25T01:56:52+0000', '2018-04-18T13:45:46+0000',
#        '2019-09-08T18:21:21+0000', '2019-07-25T19:53:21+0000',
#        '2015-06-29T23:58:09+0000', '2015-02-07T13:06:43+0000',
#        '2019-09-20T01:50:51+0000', '2019-02-18T12:02:48+0000',
#        '2013-10-10T13:57:39+0000', '2017-06-16T18:44:33+0000',
#        '2015-12-25T12:28:30+0000', '2019-09-13T06:08:17+0000',
#        '2019-09-10T16:43:35+0000', '2019-09-09T17:05:17+0000',
# ...

# %%
pd.set_option("display.max_columns", None)
no_adoptable=dataset[dataset["status"]!="adoptable"]
no_adoptable
# Out:
#              id  org_id                                                url  \
# 644    41330726   NV173  https://www.petfinder.com/dog/gunther-gunny-41...
# 5549   38169117   AZ414  https://www.petfinder.com/dog/annabelle-annie-...
# 10888  45833989    NY98  https://www.petfinder.com/dog/pepper-courtesy-...
# 11983  45515547    NY98  https://www.petfinder.com/dog/cooper-courtesy-...
# 12495  45294115    NY98  https://www.petfinder.com/dog/daisy-courtesy-l...
# 12600  45229004  NY1436  https://www.petfinder.com/dog/elmo-momo-452290...
# 12613  45227052  NY1436  https://www.petfinder.com/dog/bianca-pinky-452...
# 17619  45569380  CA1209  https://www.petfinder.com/dog/baby-girl-455693...
# 18611  44694387   MD295  https://www.petfinder.com/dog/king-bert-bertie...
# 19747  36978896   VA127  https://www.petfinder.com/dog/maddie-cutie-pat...
# 19845  33218331   VA127  https://www.petfinder.com/dog/bucky-are-u-my-h...
# ...

# %%
righe_con_00 = dataset[dataset['status'].astype(str).str.endswith("00")]
dataset.loc[righe_con_00.index, 'status'] = np.nan

# %%
no_adoptable=dataset[dataset["status"]!="adoptable"]
no_adoptable
# Out:
#              id  org_id                                                url  \
# 644    41330726   NV173  https://www.petfinder.com/dog/gunther-gunny-41...
# 5549   38169117   AZ414  https://www.petfinder.com/dog/annabelle-annie-...
# 10888  45833989    NY98  https://www.petfinder.com/dog/pepper-courtesy-...
# 11983  45515547    NY98  https://www.petfinder.com/dog/cooper-courtesy-...
# 12495  45294115    NY98  https://www.petfinder.com/dog/daisy-courtesy-l...
# 12600  45229004  NY1436  https://www.petfinder.com/dog/elmo-momo-452290...
# 12613  45227052  NY1436  https://www.petfinder.com/dog/bianca-pinky-452...
# 17619  45569380  CA1209  https://www.petfinder.com/dog/baby-girl-455693...
# 18611  44694387   MD295  https://www.petfinder.com/dog/king-bert-bertie...
# 19747  36978896   VA127  https://www.petfinder.com/dog/maddie-cutie-pat...
# 19845  33218331   VA127  https://www.petfinder.com/dog/bucky-are-u-my-h...
# ...

# %% [markdown]
# **2. For each (primary) breed, determine the number of dogs**

# %%
breed_counts = dataset.groupby("breed_primary").size()
breed_counts
# Out:
# breed_primary
# Affenpinscher                         17
# Afghan Hound                           4
# Airedale Terrier                      19
# Akbash                                 3
# Akita                                181
#                                     ...
# Wirehaired Pointing Griffon            1
# Wirehaired Terrier                    60
# Xoloitzcuintli / Mexican Hairless     11
# Yellow Labrador Retriever            158
# Yorkshire Terrier                    360
# Length: 216, dtype: int64

# %% [markdown]
# **3. For each (primary) breed, determine the ratio between the number of dogs of Mixed Breed and those not of Mixed Breed. Hint: look at the secondary_breed.**

# %%
dataset['mixed_breed2'] = dataset['breed_primary'] != dataset['breed_secondary']

total_counts = dataset.groupby('breed_primary')['mixed_breed2'].count()

mixed_counts = dataset[dataset['mixed_breed2'] == True].groupby('breed_primary')['mixed_breed2'].count()
non_mixed_counts = total_counts - mixed_counts

percent_mixed = (mixed_counts / total_counts) * 100
percent_non_mixed = 100 - percent_mixed

result_df = pd.DataFrame({'N° Mixed Dog': mixed_counts, 'N° Non Mixed Dog': non_mixed_counts, 
                          'percent mixed': percent_mixed.map('{:.2f}%'.format), 
                          'percent non mixed': percent_non_mixed.map('{:.2f}%'.format)})

print(result_df)
# Out:
#                                    N° Mixed Dog  N° Non Mixed Dog  \
# breed_primary
# Affenpinscher                                17                 0
# Afghan Hound                                  4                 0
# Airedale Terrier                             19                 0
# Akbash                                        3                 0
# Akita                                       181                 0
# ...                                         ...               ...
# Wirehaired Pointing Griffon                   1                 0
# Wirehaired Terrier                           60                 0
# Xoloitzcuintli / Mexican Hairless            11                 0
# Yellow Labrador Retriever                   158                 0
# Yorkshire Terrier                           360                 0
#
#                                   percent mixed percent non mixed
# breed_primary
# Affenpinscher                           100.00%             0.00%
# ...

# %%
dataset['y_mix']=dataset['breed_secondary']=='Mixed Breed'
dataset['n_mix']=dataset['breed_secondary']!='Mixed Breed'
ratio= dataset[['breed_primary', 'y_mix', 'n_mix']].groupby('breed_primary').sum() 
ratio['ratio']=ratio['y_mix']/ratio['n_mix']
ratio
# Out:
#                                    y_mix  n_mix     ratio
# breed_primary
# Affenpinscher                          1     16  0.062500
# Afghan Hound                           0      4  0.000000
# Airedale Terrier                       1     18  0.055556
# Akbash                                 0      3  0.000000
# Akita                                  6    175  0.034286
# ...                                  ...    ...       ...
# Wirehaired Pointing Griffon            0      1  0.000000
# Wirehaired Terrier                     4     56  0.071429
# Xoloitzcuintli / Mexican Hairless      0     11  0.000000
# Yellow Labrador Retriever              0    158  0.000000
# Yorkshire Terrier                     15    345  0.043478
#
# [216 rows x 3 columns]

# %%
import pandas as pd


total_counts = dataset.groupby('breed_primary')['breed_mixed'].count()

mixed_counts = dataset[dataset['breed_mixed'] == True].groupby('breed_primary')['breed_mixed'].count()
non_mixed_counts = total_counts - mixed_counts

percent_mixed = (mixed_counts / total_counts) * 100
percent_non_mixed = 100 - percent_mixed

result_df2 = pd.DataFrame({'N° Mixed Dog': mixed_counts, 'N° Non Mixed Dog': non_mixed_counts, 
                          'percent mixed': percent_mixed.map('{:.2f}%'.format), 
                          'percent non mixed': percent_non_mixed.map('{:.2f}%'.format)})

# Visualizza il risultato
print(result_df2)
# Out:
#                                    N° Mixed Dog  N° Non Mixed Dog  \
# breed_primary
# Affenpinscher                               5.0              12.0
# Afghan Hound                                4.0               0.0
# Airedale Terrier                           17.0               2.0
# Akbash                                      2.0               1.0
# Akita                                      83.0              98.0
# ...                                         ...               ...
# Wirehaired Pointing Griffon                 1.0               0.0
# Wirehaired Terrier                         45.0              15.0
# Xoloitzcuintli / Mexican Hairless           5.0               6.0
# Yellow Labrador Retriever                 122.0              36.0
# Yorkshire Terrier                         203.0             157.0
#
#                                   percent mixed percent non mixed
# breed_primary
# Affenpinscher                            29.41%            70.59%
# ...

# %% [markdown]
# **4. For each (primary) breed, determine the earliest and the latest posted timestamp.**

# %%
import numpy as np

nome_colonna = "posted"

righe_non_terminanti_con_00 = dataset[~dataset[nome_colonna].str.endswith("00")]
luoghi_senza_numeri = [
    "Las Vegas",
    "Chandler",
    "Albany",
    "Saugerties",
    "Bristow",
    "Silver Spring",
    "Gettysburg",
    "Media",
    "Feasterville",
    "Paris",
    "Mooresville",
    "Ross",
    "Jeffersonville",
    "Cincinnati",
    "Paoli",
    "lake charles",
    "Albuquerque",
    "Cookeville",
    "Nashville",
    "Rustburg",
    "Midlothian",
    "Seattle"
]

righe_non_terminanti_con_00["posted"] = righe_non_terminanti_con_00["posted"].apply(lambda x: np.nan if any(luogo in x for luogo in luoghi_senza_numeri) else x)

for indice, nuovo_valore in righe_non_terminanti_con_00["posted"].items():
    dataset.at[indice, "posted"] = nuovo_valore

dataset
# Out:
# C:\Users\Piergiorgio\AppData\Local\Temp\ipykernel_19020\2394353082.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   righe_non_terminanti_con_00["posted"] = righe_non_terminanti_con_00["posted"].apply(lambda x: np.nan if any(luogo in x for luogo in luoghi_senza_numeri) else x)
#              id org_id                                                url  \
# 0      46042150  NV163  https://www.petfinder.com/dog/harley-46042150/...
# 1      46042002  NV163  https://www.petfinder.com/dog/biggie-46042002/...
# 2      46040898   NV99  https://www.petfinder.com/dog/ziggy-46040898/n...
# 3      46039877  NV202  https://www.petfinder.com/dog/gypsy-46039877/n...
# 4      46039306  NV184  https://www.petfinder.com/dog/theo-46039306/nv...
# ...

# %%
dataset["posted"] = pd.to_datetime(dataset["posted"])

def min_max_dates(series):
    return pd.Series({"earliest": series.min(), "latest": series.max()})

breed_timestamps = dataset.groupby("breed_primary")["posted"].apply(min_max_dates).reset_index()

breed_timestamps.rename(columns={"earliest": "min_posted", "latest": "max_posted"}, inplace=True)

print(breed_timestamps)
# Out:
#                          breed_primary   level_1                    posted
# 0                        Affenpinscher  earliest 2012-03-08 10:27:33+00:00
# 1                        Affenpinscher    latest 2019-09-14 10:10:51+00:00
# 2                         Afghan Hound  earliest 2017-06-29 23:28:51+00:00
# 3                         Afghan Hound    latest 2019-07-27 00:38:48+00:00
# 4                     Airedale Terrier  earliest 2014-06-13 12:59:36+00:00
# ..                                 ...       ...                       ...
# 427  Xoloitzcuintli / Mexican Hairless    latest 2019-09-08 11:15:54+00:00
# 428          Yellow Labrador Retriever  earliest 2010-05-31 00:00:00+00:00
# 429          Yellow Labrador Retriever    latest 2019-09-20 06:30:27+00:00
# 430                  Yorkshire Terrier  earliest 2012-02-04 17:14:52+00:00
# 431                  Yorkshire Terrier    latest 2019-09-20 16:56:38+00:00
#
# [432 rows x 3 columns]

# %% [markdown]
# **5. For each state, compute the sex imbalance, that is the difference between male and female dogs. In which state this imbalance is largest?**

# %%
stati_squilibrio = dataset.groupby("contact_state")["sex"].apply(lambda x: (x == "Male").sum() - (x == "Female").sum())

stato_max_squilibrio = stati_squilibrio.idxmax()
valore_max_squilibrio = stati_squilibrio.max()

print("Stato con lo squilibrio più grande:", stato_max_squilibrio)
print("Valore dello squilibrio:", valore_max_squilibrio)
# Out:
# Stato con lo squilibrio più grande: OH
# Valore dello squilibrio: 208

# %% [markdown]
# **6. For each pair (age, size), determine the average duration of the stay and the average cost of stay.**

# %%
raggruppamento = dataset.groupby(["age", "size"]).agg({
    "stay_duration": "mean",
    "stay_cost": "mean"
}).reset_index()

print(raggruppamento)
# Out:
#        age         size  stay_duration   stay_cost
# 0    Adult  Extra Large      89.015414  232.591561
# 1    Adult        Large      89.531943  238.661141
# 2    Adult       Medium      89.421036  238.258977
# 3    Adult        Small      89.407479  238.974838
# 4     Baby  Extra Large      87.032967  237.180879
# 5     Baby        Large      89.701564  238.698827
# 6     Baby       Medium      89.577668  237.108131
# 7     Baby        Small      89.958291  239.083810
# 8   Senior  Extra Large      88.861111  235.232361
# 9   Senior        Large      88.984298  237.507364
# 10  Senior       Medium      89.810052  238.514615
# 11  Senior        Small      89.073626  238.282286
# 12   Young  Extra Large      90.586345  245.835582
# 13   Young        Large      90.104206  238.149506
# 14   Young       Medium      89.515123  239.304603
# 15   Young        Small      89.814275  241.540069

# %% [markdown]
# **7. Find the dogs involved in at least 3 travels. Also list the breed of those dogs.**

# %%
viaggi_per_cane = dataset1["id"].value_counts()

cani_almeno_3_viaggi = viaggi_per_cane[viaggi_per_cane >= 3]

dataset_cani_almeno_3_viaggi = dataset[dataset["id"].isin(cani_almeno_3_viaggi.index)]

elenco_razze = dataset_cani_almeno_3_viaggi[["id", "breed_primary"]].drop_duplicates()

print("Cani coinvolti in almeno 3 viaggi e le loro razze:")
print(elenco_razze)
# Out:
# Cani coinvolti in almeno 3 viaggi e le loro razze:
#              id        breed_primary
# 1159   45642530                Jindo
# 6835   46039420        Border Collie
# 8526   40036107     Pit Bull Terrier
# 10681  45851842   Labrador Retriever
# 10803  45841145          Mixed Breed
# ...         ...                  ...
# 56850  41144335            Chihuahua
# 56864  40103682          Rat Terrier
# 56875  38664932     Pit Bull Terrier
# 56879  38495992     Pit Bull Terrier
# 57263  45588395  German Shepherd Dog
#
# [563 rows x 2 columns]

# %% [markdown]
# **8. Fix the travels table so that the correct state is computed from the manual and the found fields. If manual is not missing, then it overrides what is stored in found.**

# %%
def calculate_correct_state(row):
    if not pd.isnull(row["manual"]):
        return row["manual"]
    else:
        return row["found"]

dataset1["correct_state"] = dataset1.apply(calculate_correct_state, axis=1)
dataset1
# Out:
#       index        id    contact_city contact_state  \
# 0         0  44520267           Anoka            MN
# 1         1  44698509       Groveland            FL
# 2         2  45983838       Adamstown            MD
# 3         3  44475904     Saint Cloud            MN
# 4         4  43877389          Pueblo            CO
# ...     ...       ...             ...           ...
# 6189   6189  40492179        Fairmont            WV
# 6190   6190  45799729  Eagle Mountain            UT
# 6191   6191  34276515          Newnan            GA
# 6192   6192  44519341          Dayton            OH
# 6193   6193  36659999        New York            NY
#
#                                             description        found  \
# 0     Boris is a handsome mini schnauzer who made hi...     Arkansas
# 1     Duke is an almost 2 year old Potcake from Abac...       Abacos
# 2     Zac Woof-ron is a heartthrob movie star lookin...         Adam
# ...

# %%
indices=dataset1[dataset1['manual'].notnull()].index
dataset1['found'][indices]=dataset1['manual'][indices]
dataset1
# Out:
# C:\Users\Piergiorgio\AppData\Local\Temp\ipykernel_19020\2005693385.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset1['found'][indices]=dataset1['manual'][indices]
#       index        id    contact_city contact_state  \
# 0         0  44520267           Anoka            MN
# 1         1  44698509       Groveland            FL
# 2         2  45983838       Adamstown            MD
# 3         3  44475904     Saint Cloud            MN
# 4         4  43877389          Pueblo            CO
# ...     ...       ...             ...           ...
# 6189   6189  40492179        Fairmont            WV
# 6190   6190  45799729  Eagle Mountain            UT
# 6191   6191  34276515          Newnan            GA
# 6192   6192  44519341          Dayton            OH
# ...

# %% [markdown]
# Esercizio 8 da vedere se giusto

# %% [markdown]
# **9. For each state, compute the ratio between the number of travels and the population.**

# %%
nuova_riga = {'Alabama': 'Alabama', '5.024.279': '5.024.279'}

nuovo_df = pd.DataFrame([nuova_riga])

dataset2 = pd.concat([dataset2, nuovo_df], ignore_index=True)

nuovi_nomi_colonne = {'Alabama': 'state', '5.024.279': 'population'}
dataset2.rename(columns=nuovi_nomi_colonne, inplace=True)
dataset2
# Out:
#                    state  population
# 0                 Alaska     733.391
# 1                Arizona   7.151.502
# 2               Arkansas   3.011.524
# 3             California  39.538.223
# 4               Colorado   5.773.714
# 5            Connecticut   3.605.944
# 6               Delaware     989.948
# 7   District of Columbia     689.545
# 8                Florida  21.538.187
# 9                Georgia  10.711.908
# 10                Hawaii   1.455.271
# 11                 Idaho   1.839.106
# 12              Illinois  12.812.508
# 13               Indiana   6.785.528
# 14                  Iowa   3.190.369
# 15                Kansas   2.937.880
# 16              Kentucky   4.505.836
# 17             Louisiana   4.657.757
# 18                 Maine   1.362.359
# 19              Maryland   6.177.224
# 20         Massachusetts   7.029.917
# 21              Michigan  10.077.331
# 22             Minnesota   5.706.494
# 23           Mississippi   2.961.279
# ...

# %%
viaggi_per_stato = dataset1.groupby("correct_state")["id"].count()

dataset2["numero_viaggi"] = dataset2["state"].map(viaggi_per_stato)

# %%
dataset2['population'] = dataset2['population'].str.replace('.', '', regex=True).astype(float)

dataset2['rapporto_viaggi_population'] = dataset2['numero_viaggi'] / dataset2['population']
dataset2
# Out:
#                    state  population  numero_viaggi  \
# 0                 Alaska    733391.0            NaN
# 1                Arizona   7151502.0           33.0
# 2               Arkansas   3011524.0           61.0
# 3             California  39538223.0          279.0
# 4               Colorado   5773714.0           11.0
# 5            Connecticut   3605944.0           16.0
# 6               Delaware    989948.0           27.0
# 7   District of Columbia    689545.0            NaN
# 8                Florida  21538187.0          163.0
# 9                Georgia  10711908.0          235.0
# 10                Hawaii   1455271.0            4.0
# 11                 Idaho   1839106.0            4.0
# 12              Illinois  12812508.0           33.0
# 13               Indiana   6785528.0           17.0
# 14                  Iowa   3190369.0            7.0
# 15                Kansas   2937880.0            3.0
# 16              Kentucky   4505836.0           99.0
# ...

# %% [markdown]
# **10. For each dog, compute the number of days from the posted day to the day of last access.**

# %%
dataset['posted'] = pd.to_datetime(dataset['posted'])
dataset['accessed'] = pd.to_datetime(dataset['accessed'])

dataset['posted'] = dataset['posted'].dt.date
dataset['accessed'] = dataset['accessed'].dt.date

dataset['differenza_giorni'] = (dataset['accessed'] - dataset['posted']).dt.days

dataset
# Out:
#              id org_id                                                url  \
# 0      46042150  NV163  https://www.petfinder.com/dog/harley-46042150/...
# 1      46042002  NV163  https://www.petfinder.com/dog/biggie-46042002/...
# 2      46040898   NV99  https://www.petfinder.com/dog/ziggy-46040898/n...
# 3      46039877  NV202  https://www.petfinder.com/dog/gypsy-46039877/n...
# 4      46039306  NV184  https://www.petfinder.com/dog/theo-46039306/nv...
# ...         ...    ...                                                ...
# 58175  44605893   WY20  https://www.petfinder.com/dog/tren-44605893/wy...
# 58176  44457061   WY24  https://www.petfinder.com/dog/harley-44457061/...
# 58177  42865848   WY20  https://www.petfinder.com/dog/echo-42865848/wy...
# 58178  42734734   WY24  https://www.petfinder.com/dog/simon-42734734/w...
# 58179  42663515   WY24  https://www.petfinder.com/dog/romeo-42663515/w...
#
#       type.x species                   breed_primary  \
# ...

# %%
dataset['posted'] = pd.to_datetime(dataset['posted'])
dataset['accessed'] = pd.to_datetime(dataset['accessed'])

dataset['posted'] = dataset['posted'].dt.date
dataset['accessed'] = dataset['accessed'].dt.date

dataset['diff']=dataset['accessed']-dataset['posted']
dataset
# Out:
#              id org_id                                                url  \
# 0      46042150  NV163  https://www.petfinder.com/dog/harley-46042150/...
# 1      46042002  NV163  https://www.petfinder.com/dog/biggie-46042002/...
# 2      46040898   NV99  https://www.petfinder.com/dog/ziggy-46040898/n...
# 3      46039877  NV202  https://www.petfinder.com/dog/gypsy-46039877/n...
# 4      46039306  NV184  https://www.petfinder.com/dog/theo-46039306/nv...
# ...         ...    ...                                                ...
# 58175  44605893   WY20  https://www.petfinder.com/dog/tren-44605893/wy...
# 58176  44457061   WY24  https://www.petfinder.com/dog/harley-44457061/...
# 58177  42865848   WY20  https://www.petfinder.com/dog/echo-42865848/wy...
# 58178  42734734   WY24  https://www.petfinder.com/dog/simon-42734734/w...
# 58179  42663515   WY24  https://www.petfinder.com/dog/romeo-42663515/w...
#
#       type.x species                   breed_primary  \
# ...

# %% [markdown]
# **11. Partition the dogs according to the number of weeks from the posted day to the day of last access.**

# %%
dataset['posted'] = pd.to_datetime(dataset['posted'])
dataset['accessed'] = pd.to_datetime(dataset['accessed'])

dataset['settimane_differenza'] = (dataset['accessed'] - dataset['posted']).dt.days // 7

bins = [-1, 4, 8, 12, float('inf')]  # Definisco gli intervalli delle settimane
labels = ['0-4 settimane', '5-8 settimane', '9-12 settimane', 'oltre 12 settimane']

dataset['settimane_partition'] = pd.cut(dataset['settimane_differenza'], bins=bins, labels=labels)

dataset
# Out:
#              id org_id                                                url  \
# 0      46042150  NV163  https://www.petfinder.com/dog/harley-46042150/...
# 1      46042002  NV163  https://www.petfinder.com/dog/biggie-46042002/...
# 2      46040898   NV99  https://www.petfinder.com/dog/ziggy-46040898/n...
# 3      46039877  NV202  https://www.petfinder.com/dog/gypsy-46039877/n...
# 4      46039306  NV184  https://www.petfinder.com/dog/theo-46039306/nv...
# ...         ...    ...                                                ...
# 58175  44605893   WY20  https://www.petfinder.com/dog/tren-44605893/wy...
# 58176  44457061   WY24  https://www.petfinder.com/dog/harley-44457061/...
# 58177  42865848   WY20  https://www.petfinder.com/dog/echo-42865848/wy...
# 58178  42734734   WY24  https://www.petfinder.com/dog/simon-42734734/w...
# 58179  42663515   WY24  https://www.petfinder.com/dog/romeo-42663515/w...
#
#       type.x species                   breed_primary  \
# ...

# %% [markdown]
# **12. Find for duplicates in the dogs dataset. Two records are duplicates if they have (1) same breeds and sex, and (2) they share at least 90% of the words in the description field. Extra points if you find and implement a more refined for determining if two rows are duplicates.**

# %%
#cond1
no_null=dataset[dataset['description'].notna()]
no_null
a=no_null[['breed_primary', 'breed_secondary', 'sex', 'id']].groupby(['breed_primary', 'breed_secondary','sex']).count()
a= a[a['id']!=1].reset_index()
a= a.rename(columns={"id": "number"})
a

#extract id
dicti={}
for j in range(len(a)):
    dicti[j]=no_null[(no_null['breed_primary']==a.iloc[j]['breed_primary']) & (no_null['breed_secondary']==a.iloc[j]['breed_secondary'])&(no_null['sex']==a.iloc[j]['sex'])]['id']
dicti

#put id in the dataset
for i in range(len(dicti)):
    dicti[i]=dicti[i].values.tolist()
a['id_list']=dicti.values()
a

#from the dataset 'no_null', extract description associated to specific id in 
list_id = a['id_list']
b=[]
lista_def=[]
for i in range(len(list_id)):
    b=[]
    for k in range(len(list_id[i])):
        b.append(no_null[no_null['id']==list_id[i][k]]['description'].values[0])
    lista_def.append(b)
    

a['description']=lista_def
a
import nltk

from nltk.cluster.util import cosine_distance
import numpy as np
def get_cosine_similarity(sentence1, sentence2, stopwords=None):
    if stopwords is None:
        stopwords = []

    sentence1 = [w.lower() for w in sentence1]
    sentence2 = [w.lower() for w in sentence2]
    words_all = list(set(sentence1 + sentence2))

    array1 = [0] * len(words_all)
    array2 = [0] * len(words_all)

    for w in sentence1:
        if w in stopwords:
            continue
        array1[words_all.index(w)] += 1

    for w in sentence2:
        if w in stopwords:
            continue
        array2[words_all.index(w)] += 1
    return 1 - cosine_distance(array1, array2)

for i in range(len(list_id)):
    for j in range(len(list_id[i])):
        for k in range(len(list_id[i])-1,j,-1):
            x= a['description'][i][j]
            y= a['description'][i][k]
            if get_cosine_similarity(x,y, stopwords=None)>=0.9:
                S1=x
                S2=y
                Cos=get_cosine_similarity(x,y, stopwords=None)
print(f"\033[1mThe first sentence is \033[0m \n{x}\n\033[1mThe second sentence is \033[0m\n{y} \n\n\033[1mThe similarity value is equal to\033[0m {get_cosine_similarity(x,y,stopwords=None)} \n \n ")

import time 
start=time.time()
id_1=[]
id_2=[]
descr_1=[]
descr_2=[]
sim=[]
for i in range(len(list_id)):
    for j in range(len(list_id[i])):
        for k in range(len(list_id[i])-1,j,-1):
            x= a['description'][i][j]
            y= a['description'][i][k]
            if get_cosine_similarity(x,y, stopwords=None)>=0.9:
                id_1.append(a['id_list'][i][j])
                id_2.append(a['id_list'][i][k])
                descr_1.append(x)
                descr_2.append(y)
                sim.append(get_cosine_similarity(x,y, stopwords=None))
end=time.time()
t=end-start
final={'id_1':id_1, 'descr_1':descr_1, 'id_2':id_2, 'descr_2':descr_2, 'similarity':sim}
pd.DataFrame.from_dict(final)
# Out:
# The first sentence is
# Bam Bam is approximately a 1 year old Yorkshire Terrier/Wire Haired Terrier ready to find his loving forever home!
#
# Bam Bam is a sweet, & loving boy whom is a gorgeous little boy who loves everyone including kids, and other dogs.  His favorite thing to do is to play, & to be by your side or in your lap.
#
# Bam Bam is fixed, microchipped and vaccinated. He would be a great addition to any family.
#
# Fill out an application today to set up a meet & greet with this sweet boy!!
#
# Application, Reference check, Home check and adoption fee apply.
#
# BRAT Rescue, Inc. at this time conducts adoptions in the Five (5) boroughs of NYC, Long Island, and Southern Westchester County.
#
# BRAT RESCUE INC., is a 501c3 tax exempt organization that rescues dog's and feeds feral animals in Far Rockaway and neighboring towns in Queens and the five boroughs of NYC.
# The second sentence is
# ...

# %%
#minutes
t/60
# Out:
# 13.532622929414114
